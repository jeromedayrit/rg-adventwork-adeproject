# %%
# Define storage account and directory
storage_account_name = "saprojectadventworks "
mount_point_bronze = "/mnt/bronze"
mount_point_silver = "/mnt/silver"
mount_point_gold = "/mnt/gold"

# %%
# Define credentials
client_id = "8468304b-6539-47ec-a8c5-59fd7580a0c0"  # Application (Client) ID
tenant_id = "1b265b94-d50f-4b63-b12e-59c2a45ef1ca"  # Directory (Tenant) ID
client_secret = "0cY8Q~pX5zoaPOgH95ndX9PcfnNaZusnKSqxLaX."

# %%
# OAuth Configuration
configs = {
    "fs.azure.account.auth.type": "OAuth",
    "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
    "fs.azure.account.oauth2.client.id": client_id,
    "fs.azure.account.oauth2.client.secret": client_secret,
    "fs.azure.account.oauth2.client.endpoint": f"https://login.microsoftonline.com/{tenant_id}/oauth2/token"
}

# %%
# Mount ADLS Gen2 Bronze
dbutils.fs.mount(
    source=f"abfss://bronze@saprojectadventworks.dfs.core.windows.net/",
    mount_point=mount_point_bronze,
    extra_configs=configs
)
# Out:
# ---------------------------------------------------------------------------
# ExecutionError                            Traceback (most recent call last)
# File <command-7678107281208001>, line 2
#       1 # Mount ADLS Gen2 Bronze
# ----> 2 dbutils.fs.mount(
#       3     source=f"abfss://bronze@saprojectadventworks.dfs.core.windows.net/",
#       4     mount_point=mount_point_bronze,
#       5     extra_configs=configs
#       6 )
#
# File /databricks/python_shell/lib/dbruntime/dbutils.py:158, in prettify_exception_message.<locals>.f_with_exception_handling(*args, **kwargs)
#     156 exc.__context__ = None
#     157 exc.__cause__ = None
# --> 158 raise exc
#
# ExecutionError: An error occurred while calling o422.mount.
# : java.rmi.RemoteException: java.lang.IllegalArgumentException: requirement failed: Directory already mounted: /mnt/bronze; nested exception is:
# 	java.lang.IllegalArgumentException: requirement failed: Directory already mounted: /mnt/bronze
# ...

# %%
# Mount ADLS Gen2 Silver
dbutils.fs.mount(
    source=f"abfss://silver@saprojectadventworks.dfs.core.windows.net/",
    mount_point=mount_point_silver,
    extra_configs=configs
)
# Out:
# ---------------------------------------------------------------------------
# ExecutionError                            Traceback (most recent call last)
# File <command-7678107281208002>, line 2
#       1 # Mount ADLS Gen2 Silver
# ----> 2 dbutils.fs.mount(
#       3     source=f"abfss://silver@saprojectadventworks.dfs.core.windows.net/",
#       4     mount_point=mount_point_silver,
#       5     extra_configs=configs
#       6 )
#
# File /databricks/python_shell/lib/dbruntime/dbutils.py:158, in prettify_exception_message.<locals>.f_with_exception_handling(*args, **kwargs)
#     156 exc.__context__ = None
#     157 exc.__cause__ = None
# --> 158 raise exc
#
# ExecutionError: An error occurred while calling o422.mount.
# : java.rmi.RemoteException: java.lang.IllegalArgumentException: requirement failed: Directory already mounted: /mnt/silver; nested exception is:
# 	java.lang.IllegalArgumentException: requirement failed: Directory already mounted: /mnt/silver
# ...

# %%
# Mount ADLS Gen2 Silver
dbutils.fs.mount(
    source=f"abfss://gold@saprojectadventworks.dfs.core.windows.net/",
    mount_point=mount_point_gold,
    extra_configs=configs
)
# Out:
# True

# %%
# Verify the mount
display(dbutils.fs.ls(mount_point_gold))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/mnt/gold/Capture.JPG</td><td>Capture.JPG</td><td>12792</td><td>1744167606000</td></tr></tbody></table></div>
